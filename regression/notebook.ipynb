# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# Import the necessary modules.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection # Here model_selection is used for splitting data into training and test sets

# %% [markdown]
# Now, load X and y data. Remember, this is a supervised learning and we need a named 'y' target.
# Load the diabetes dataset. Ten baseline variables, age, sex, body mass index, average blood pressure, and six blood serum measurements were obtained for each of n = 442 diabetes patients, as well as the response of interest, a quantitative measure of disease progression one year after baseline.
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of n_samples (i.e. the sum of squares of each column totals 1).

# %%
# return_X_y signals that X will be the data matrix and y will be the regression target.
# What you are getting back in a response is a tuple
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
X = X[:, 2] # select 3rd column of the data matrix
X = X.reshape((-1, 1)) # reshape to a 2D array with one column
print(X.shape)
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]
# (442, 1)

# %% [markdown]
# Now, perform the logical split between the data. Split both data X and feature y into test and training set.

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %% [markdown]
# Now we are ready to train our model. Load up the linear regression model and train it with our X and y training sets using model.fit():

# %%
# Create a linear regression model and fit it to the training data.
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then create a prediction using test data, using the function predict(). This will be used to draw the line between data groups.

# %%
y_pred = model.predict(X_test)
print(X_test[:5])
print(y_pred[:5])
# Out:
# [[ 0.03043966]
#  [ 0.02397278]
#  [-0.03961813]
#  [ 0.04445121]
#  [ 0.05846277]]
# [183.6003228  177.2173641  114.45160358 197.43006664 211.25981048]

# %% [markdown]
# Now, it's time to show the data in a plot.

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMI')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()
